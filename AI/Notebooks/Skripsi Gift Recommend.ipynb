# %%
import pandas as pd

# %%
df=pd.read_csv("gift_recommendation_data (1).csv")
df
# Out:
#        Unnamed: 0  ...                                       product_name
# 0               0  ...       Nice Facial Pop Up 200's  Multi Pack [5 pcs]
# 1               2  ...                               Edifier X3 TWS Black
# 2               4  ...         SUNLIGHT Mint Sabun Cuci Piring [755 mL] -
# 3               8  ...  Airwalk Kelmer Sepatu Pria - Navy [AIWS18CV010...
# 4              10  ...      Downy Pelembut Pakaian Passion Botol [900 mL]
# ...           ...  ...                                                ...
# 31629     9975418  ...  Bimoli Klasik Pouch Minyak Goreng [2000 mL/6 pcs]
# 31630     9976088  ...  SHARP R-751GX(BS) Microwave Grill Inverter [25...
# 31631     9977869  ...  Samsung Galaxy M10 Smartphone [16GB/ 2GB] Ocea...
# 31632     9979186  ...  Christian Dior Sauvage Share Favorit 91 EDP Pa...
# 31633     9998880  ...  INFINIX NOTE 8 RAM 6/128GB - GARANSI RESMI SIL...
#
# [31634 rows x 9 columns]

# %%
df=df.dropna()

# %%
df
# Out:
#        Unnamed: 0  ...                                       product_name
# 2               4  ...         SUNLIGHT Mint Sabun Cuci Piring [755 mL] -
# 12             21  ...                   Bullsone - VOGUE Espresso Coklat
# 19             28  ...           Pliko 518AL Mini Kereta Dorong Bayi Grey
# 71            157  ...  Nice Soft Facial Tissue [200 sheets / 2 ply / ...
# 76            162  ...  Kuat Harimau Lemon Segar Detergent Powder [900...
# ...           ...  ...                                                ...
# 31496     9720737  ...  realme 6 Pro Smartphone [8GB/ 128GB] - Lightni...
# 31517     9757290  ...  Babyland New Pocket Froggie Baby Clodi with 1 ...
# 31558     9831595  ...     Sustagen Junior 1+ Madu Susu Formula Tin 800gr
# 31591     9892531  ...  Elfs Shop Nilon Spandek Garis Kaos Kaki Sepak ...
# 31613     9938289  ...      OEM Hammock Kasur Gantung Camping Salur merah
#
# [1501 rows x 9 columns]

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
from keras.utils import np_utils
from sklearn import preprocessing

# %%
df["status"]
# Out:
# 2        MARRIED
# 12       MARRIED
# 19       MARRIED
# 71       MARRIED
# 76        SINGLE
#           ...
# 31496    MARRIED
# 31517    MARRIED
# 31558    MARRIED
# 31591    MARRIED
# 31613     SINGLE
# Name: status, Length: 1501, dtype: object

# %%
encoder =  preprocessing.LabelEncoder()
encoder.fit(df["status"])
encoded_status = encoder.transform(df["status"])

# %%
df["status"]=encoded_status

# %%
encoder =  preprocessing.LabelEncoder()
encoder.fit(df["gender"])
encoded_gender = encoder.transform(df["gender"])

# %%
df["gender"]=encoded_gender

# %%
occ=pd.get_dummies(df["occ1"])
df=pd.concat([df,occ],axis=1)
df=df.drop('occ1',axis=1)

# %%
df=df.drop('occ2',axis=1)

# %%
import numpy as np

# %%
df['Gadget'] = np.where(df['interests'].str.contains(pat='GADGET'),1,0)

# %%
df['MakeUp'] = np.where(df['interests'].str.contains(pat='MAKE_UP_AND_SKIN_CARE'),1,0)

# %%
df['Fashion'] = np.where(df['interests'].str.contains(pat='FASHION'),1,0)

# %%
df['Art'] = np.where(df['interests'].str.contains(pat='ART'),1,0)

# %%
df['Photography'] = np.where(df['interests'].str.contains(pat='PHOTOGRAPHY'),1,0)

# %%
df['Automotive'] = np.where(df['interests'].str.contains(pat='AUTOMOTIVE'),1,0)

# %%
df['Books'] = np.where(df['interests'].str.contains(pat='BOOKS'),1,0)

# %%
df['Movies'] = np.where(df['interests'].str.contains(pat='MOVIES'),1,0)

# %%
df['Music'] = np.where(df['interests'].str.contains(pat='MUSIC'),1,0)

# %%
df['Interior'] = np.where(df['interests'].str.contains(pat='INTERIOR_DESIGN'),1,0)

# %%
df['Sports'] = np.where(df['interests'].str.contains(pat='SPORTS'),1,0)

# %%
df['Travelling'] = np.where(df['interests'].str.contains(pat='TRAVELLING'),1,0)

# %%
df['Culinary'] = np.where(df['interests'].str.contains(pat='CULINARY'),1,0)

# %%
df['Cooking'] = np.where(df['interests'].str.contains(pat='COOKING'),1,0)

# %%
df['Gaming'] = np.where(df['interests'].str.contains(pat='GAMING'),1,0)

# %%
df
# Out:
#        gender  age  status  ... Culinary Cooking Gaming
# 2           0   38       0  ...        1       1      0
# 12          0   35       0  ...        0       0      0
# 19          0   40       0  ...        0       0      0
# 71          1   30       0  ...        1       0      0
# 76          1   24       1  ...        1       0      0
# ...       ...  ...     ...  ...      ...     ...    ...
# 31496       1   44       0  ...        1       0      0
# 31517       0   27       0  ...        0       0      0
# 31558       0   34       0  ...        1       1      1
# 31591       0   42       0  ...        0       0      0
# 31613       1   48       1  ...        0       0      0
#
# [1501 rows x 22 columns]

# %%
df.to_csv('gift_recommendation_Filtered.csv')

# %%
df=df.drop('interests',axis=1)

# %%
df
# Out:
#        gender  age  status  ... Culinary Cooking  Gaming
# 2           0   38       0  ...        1       1       0
# 12          0   35       0  ...        0       0       0
# 19          0   40       0  ...        0       0       0
# 71          1   30       0  ...        1       0       0
# 76          1   24       1  ...        1       0       0
# ...       ...  ...     ...  ...      ...     ...     ...
# 31496       1   44       0  ...        1       0       0
# 31517       0   27       0  ...        0       0       0
# 31558       0   34       0  ...        1       1       1
# 31591       0   42       0  ...        0       0       0
# 31613       1   48       1  ...        0       0       0
#
# [1501 rows x 21 columns]

# %%
encoder =  preprocessing.LabelEncoder()
encoder.fit(df["category_name"])
encoded_category = encoder.transform(df["category_name"])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
x = df['age'].values.reshape(-1, 1) #returns a numpy array
min_max_scaler = MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
df['age'] = x_scaled

# %%
encoded_category
# Out:
# array([342, 311, 189, ..., 445,   6,  15])

# %%
max_value= encoded_category.max()

# %%
max_value
# Out:
# 500

# %%
min_value= encoded_category.min()

# %%
min_value
# Out:
# 0

# %%
from sklearn.model_selection import train_test_split

# %%
df_train, df_test = train_test_split(df, test_size=0.3)

# %%
x_train = df_train.drop('category_name',axis=1)
x_train = x_train.drop('product_name',axis=1)

# %%
y_train = df_train['category_name']

# %%
x_train
# Out:
#        gender       age  status  OTHERS  ...  Travelling  Culinary  Cooking  Gaming
# 3267        1  0.757143       0       1  ...           0         1        1       1
# 14255       1  0.342857       1       1  ...           0         1        0       0
# 18872       0  0.500000       0       1  ...           0         0        0       1
# 6620        0  0.500000       1       1  ...           0         1        0       0
# 21278       0  0.385714       0       1  ...           0         1        0       1
# ...       ...       ...     ...     ...  ...         ...       ...      ...     ...
# 18814       1  0.371429       0       1  ...           0         0        0       0
# 13788       0  0.557143       1       1  ...           1         0        1       0
# 30234       0  0.828571       0       1  ...           0         0        0       0
# 23329       1  0.514286       0       1  ...           0         1        1       0
# ...

# %%
y_train
# Out:
# 3267                  Bumbu Masak
# 14255       Perawatan Kulit Badan
# 18872    Rumah Boneka & Aksesoris
# 6620                Laptop (1868)
# 21278                 Game Islami
#                    ...
# 18814              Minyak Masakan
# 13788    Pakaian Olahraga Lainnya
# 30234                 Ruang Tidur
# 23329               Digital Media
# 20946                 Memory Card
# Name: category_name, Length: 1050, dtype: object

# %%
x_test = df_test.drop('category_name',axis=1)
x_test = x_test.drop('product_name',axis=1)

# %%
y_test = df_test['category_name']

# %%
x_test
# Out:
#        gender       age  status  OTHERS  ...  Travelling  Culinary  Cooking  Gaming
# 20458       0  0.357143       1       1  ...           1         0        0       0
# 4200        0  0.542857       0       1  ...           1         1        1       0
# 11316       0  0.500000       1       1  ...           1         1        1       1
# 16733       0  0.285714       1       1  ...           0         1        1       0
# 27876       1  0.285714       1       1  ...           0         0        0       0
# ...       ...       ...     ...     ...  ...         ...       ...      ...     ...
# 26956       1  0.542857       1       1  ...           0         0        0       0
# 28250       1  0.642857       0       1  ...           0         0        0       1
# 13645       0  0.357143       0       1  ...           0         0        1       1
# 23002       1  0.471429       0       1  ...           1         1        1       1
# ...

# %%
y_test
# Out:
# 20458             Alat Pencukur
# 4200     Kesehatan Mulut & Gigi
# 11316             Makanan Halal
# 16733                      Susu
# 27876                      Helm
#                   ...
# 26956         Kesehatan Seksual
# 28250      Cairan Pembersih Ban
# 13645             Sarung Tangan
# 23002               Aneka Beras
# 4496               Riasan Bibir
# Name: category_name, Length: 451, dtype: object

# %%
from scipy import spatial

# %%
spatial.distance.cosine(x_train.iloc[0],x_train.iloc[1])
# Out:
# 0.45673229730272324

# %%
x_test.iloc[0]
# Out:
# gender         0.000000
# age            0.357143
# status         1.000000
# OTHERS         1.000000
# Gadget         0.000000
# MakeUp         1.000000
# Fashion        1.000000
# Art            1.000000
# Photography    0.000000
# Automotive     0.000000
# Books          0.000000
# Movies         0.000000
# Music          0.000000
# Interior       1.000000
# Sports         0.000000
# Travelling     1.000000
# Culinary       0.000000
# Cooking        0.000000
# Gaming         0.000000
# Name: 20458, dtype: float64

# %%
x_test.iloc[11]
# Out:
# gender         1.000000
# age            0.442857
# status         1.000000
# OTHERS         1.000000
# Gadget         1.000000
# MakeUp         0.000000
# Fashion        1.000000
# Art            0.000000
# Photography    0.000000
# Automotive     0.000000
# Books          1.000000
# Movies         0.000000
# Music          1.000000
# Interior       0.000000
# Sports         0.000000
# Travelling     0.000000
# Culinary       0.000000
# Cooking        1.000000
# Gaming         0.000000
# Name: 30903, dtype: float64

# %%
test=[x_test.iloc[0]]

# %%
test
# Out:
# [gender         0.000000
#  age            0.357143
#  status         1.000000
#  OTHERS         1.000000
#  Gadget         0.000000
#  MakeUp         1.000000
#  Fashion        1.000000
#  Art            1.000000
#  Photography    0.000000
#  Automotive     0.000000
#  Books          0.000000
#  Movies         0.000000
#  Music          0.000000
#  Interior       1.000000
#  Sports         0.000000
#  Travelling     1.000000
#  Culinary       0.000000
#  Cooking        0.000000
#  Gaming         0.000000
#  Name: 20458, dtype: float64]

# %%
print(knn.predict(test))
# Out:
# ['Air Mineral']

# %%
y_test.iloc[0]
# Out:
# 'Alat Pencukur'
