# %% [markdown]
# 1. [15%] Buka data “datasetMidExamCOMP6577.csv” yang diberikan dan lakukan analisis statistik dasar yang anda rasa perlukan untuk membantu proses learning model terhadap data tersebut. Tampilkan hasil dari analisis tersebut, dan jelaskan dengan rinci seluruh hasil dari analisis tersebut!

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as sm

data = pd.read_csv('datasetMidExamCOMP6577.csv')

lr = LinearRegression()
lr.fit(data[['X1']+['X2']+['X3']+['X4']+['X5']+['X6']+['X7']+['X8']+['X9']+['X10']+
['X11']+['X12']+['X13']+['X14']+['X15']+['X16']+['X17']+['X18']+['X19']+['X20']], data[['Y']])

predictions = lr.predict(data[["X1"]+["X2"]+["X3"]+['X4']+['X5']+['X6']+['X7']+['X8']+['X9']+['X10']+
['X11']+['X12']+['X13']+['X14']+['X15']+['X16']+['X17']+['X18']+['X19']+['X20']])

import statsmodels.formula.api as sm
model = sm.ols(formula='Y ~ X1+X2+X3+X4+X5+X6+X7+X8+X9+X10+X11+X12+X13+X14+X15+X16+X17+X18+X19+X20', data=data)
fitted1 = model.fit()
print(fitted1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      Y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 4.040e+07
# Date:                Sat, 18 Apr 2020   Prob (F-statistic):               0.00
# Time:                        23:30:01   Log-Likelihood:                -3597.8
# No. Observations:                5000   AIC:                             7238.
# Df Residuals:                    4979   BIC:                             7374.
# Df Model:                          20
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     11.6965      0.007   1657.990      0.000      11.683      11.710
# ...

# %% [markdown]
# R-Square dan Adj.Rsquare merupakan indikator bahwa data dapat di prediksi dengan baik atau tidak jika hasilnya adalah 1 maka data baik di prediksi.
#
# Coef(Coefficient) = Indikasi seberapa banyak data itu berpengaruh kepada keseluruhan model jika nilai Coef semakin besar maka semakin berpengaruh dan jika nilai semakin mendekati 0 maka semakin tidak berpengaruh.
#
# t = penghitungan perbedaan di antara populasi data dengan kata lain, semakin beasar nilai t maka semakin besar kemungkinannya bahwa data tersebut berbeda.
#
# p = kemungkinan data tersebut memiliki hubungan atau tidak.
#
# P>[t] = Indikasi seberapa berhubung data jika semakin dekat dengan 0 maka semakin berhubungan.

# %% [markdown]
# 2. [10%] Menurut anda, berdasarkan profil data tersebut, algoritma learning apa yang cocok untuk memprediksi Y berdasarkan fitur-fitur yang diberikan pada data tersebut. Jelaskan pendapat anda disertai dengan data hasil analisis!

# %% [markdown]
# Menurut saya algoritma learning yang cocok adalah linear Regression, dikarenakan linear regession merupakan predictive analysis dasar dan juga linear regresion dapat memprediksi apakah sebuah variabel berkerja dengan baik memprediksi hasil atau tidak dan juga seberapa besar pengaruh variabel dalam memprediksi hasil

# %% [markdown]
# 3. [15% ]Berdasarkan hasil dari analisis yang dilakukan sebelumnya, menurut anda fitur-fitur apa saja yang akan anda pilih untuk melakukan prediksi terhadap Y? Jelaskan dengan alasan anda:
# a. Memilih fitur-fitur tersebut sebagai predictor dari Y!
# b. Tidak Memilih fitur-fitur tersebut sebagai predictor dari Y!

# %% [markdown]
# Dari hasil statistik ajusted R-Square di atas dapat dilihat bahwa data yang berpengaruh adalah data X1,X4,X6,X8,X10,X11,X13,X14,X15,X18
# dapat di lihat dari coef dan P>[t] pada coef jika semakin beasar Coef tersebut maka data tersebut semakin berpengaruh sedangkan untuk P>[t] jika nilainya Semakin dengan 0 maka  data semakin berpengaruh.
# dengan begitu kita dapat memilih bahwa X1,X4,X6,X8,X10,X11,X13,X14,X15,X18 berperngaruh sedangkan
# sisa dari fitur tsb., X2,X3,X5,X7,X9,X12,X16,X17,X19,X20 pengaruhnya lebih insignificant

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as sm

data = pd.read_csv('datasetMidExamCOMP6577.csv')

print(data.columns.values)

lr = LinearRegression()
lr.fit(data[['X1']+['X4']+['X6']+['X8']+['X10']+
['X11']+['X13']+['X14']+['X15']+['X18']], data[['Y']])

predictions = lr.predict(data[['X1']+['X4']+['X6']+['X8']+['X10']+
['X11']+['X13']+['X14']+['X15']+['X18']])

import statsmodels.formula.api as sm
model = sm.ols(formula='Y ~ X1+X4+X6+X8+X10+X11++X13+X14+X15+X18', data=data)
fitted1 = model.fit()
print(fitted1.summary())

# %% [markdown]
# 4. [30%] Bangun sebuah learning model, dengan melakukan training dengan algoritma learning yang anda pilih pada nomor (2) dan fitur-fitur yang anda pilih pada nomor (3). Jelaskan seluruh langkah yang anda lakukan pada proses training ini.

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

data = pd.read_csv('datasetMidExamCOMP6577.csv') 

def load_data():
    x_data = data [['X1','X4','X6','X8','X10','X11','X13','X14','X15','X18']]
    y_data = data [['Y','Y','Y','Y','Y','Y','Y','Y','Y','Y']]
    return x_data, y_data

x_data, y_data = load_data()

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=0)

regressor = LinearRegression()  
regressor.fit(x_train, y_train) #training the algorithm

y_pred=regressor.predict(x_test)

plt.scatter(x_test, y_test,  color='gray')
plt.plot(x_test, y_pred, color='red', linewidth=2)
plt.show()

# %% [markdown]
# Dimulai dengan membaca file CSV dengan menggunakan panda,
# kemudian memecah data tersebut menjadi 2 data yaitu x_data dan y_data yang kemudian data tsb di pecah lagi
# menjadi x_train, x_test, y_train, y_test yang tujuannya untuk testing dan learning
# setelah itu x_test dan y_train di trainning dengan linear regression.
# Setelah itu dengan memprediksi x_test kita mendapatkan hasil prediksi yang di simpan dengan y_pred

# %% [markdown]
# 5. [15%] Lakukan evaluasi terhadap model yang anda bangun. Jelaskan hasil dari evaluasi dari learning model anda dengan menggunakan minimal 2 evaluation metrics yang sesuai dengan algoritma learning yang dipilih pada nomor (2).

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.39033802045787175
# Mean Squared Error: 0.24165157204046875
# Root Mean Squared Error: 0.49158068721265763

# %% [markdown]
# Mean Absolute Error =  memperlihatkan perbedaan antara value target dan value yang di prediksi yang dimana score yang di hitung menghitung semuanya secara sama dan di rata-ratakan
# Mean Squared Error = merata-ratakan hasil perbedaan antara predicted dan target yang di kuadratsehingga error yang di hasilkan akan lebih besar.
# Root Mean Squared Error = memperlihatkan hasil MSE yang di akar sehingga hasil error nya tidak terlalu besar.

# %% [markdown]
# 6.[15%] Jelaskan dengan data dan/atau simulasi, masalah apa yang mungkin akan muncul, jika anda menggunakan:
# a. Hanya 1 fitur saja untuk melakukan prediksi terhadap Y. Fitur mana yang dapat dipilih?
# b. Menggunakan seluruh fitur (X1 - X20) untuk melakukan prediksi terhadap Y.

# %% [markdown]
# a. Jika 1 fitur saja yang digunakan maka X8 yang dapat digunakan karena memiliki nilai coefisien yang tinggi jika di bandingkan dengan seluruhnya tapi dapat menghasilkan data dengan error yang lebih tinggi

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

data = pd.read_csv('datasetMidExamCOMP6577.csv') 

def load_data():
    x_data = data [['X8']]
    y_data = data [['Y']]
    return x_data, y_data

x_data, y_data = load_data()

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=0)

regressor = LinearRegression()  
regressor.fit(x_train, y_train) #training the algorithm

y_pred=regressor.predict(x_test)

plt.scatter(x_test, y_test,  color='gray')
plt.plot(x_test, y_pred, color='red', linewidth=2)
plt.show()
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 140.8516205907932
# Mean Squared Error: 31437.738434446088
# Root Mean Squared Error: 177.30690464402701

# %% [markdown]
# b. jika menggunakan seluruh fitur untuk prediksi Y dapat menghasilkan hasil yang lebih menjanjikan tapi kekurangannya adalah tidak semua data penting atau memiliki pengaruh yang besar sehingga system tidak terlalu effective. Dapat di contohkan apabila dengan meggunakan 5 data dapat menghasilkan hasil yang sama dengan 20 data maka lebih baik menggunakan 5 data.

# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt  
import seaborn as seabornInstance 
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics

data = pd.read_csv('datasetMidExamCOMP6577.csv') 

def load_data():
    x_data = data [['X1','X2','X3','X4','X5','X6','X7','X8','X9','X10','X11','X12','X13','X14','X15','X16','X17','X18','X19','X20']]
    y_data = data [['Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y','Y']]
    return x_data, y_data

x_data, y_data = load_data()

x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=0)

regressor = LinearRegression()  
regressor.fit(x_train, y_train) #training the algorithm

y_pred=regressor.predict(x_test)

plt.scatter(x_test, y_test,  color='gray')
plt.plot(x_test, y_pred, color='red', linewidth=2)
plt.show()

print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.39232821122090655
# Mean Squared Error: 0.24359017002299796
# Root Mean Squared Error: 0.4935485488004174

# %% [markdown]
# Refrence
# https://statinfer.com/204-1-7-adjusted-r-squared-in-python/
# https://towardsdatascience.com/a-beginners-guide-to-linear-regression-in-python-with-scikit-learn-83a8f7ae2b4f
