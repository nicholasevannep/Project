# %% [markdown]
# 1 A

# %%
 import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist

# %%
pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading https://files.pythonhosted.org/packages/6f/4b/bab676953da3103003730b8fcdfadbdd20f333d4add10af949dd5c51e6ed/Sastrawi-1.0.1-py2.py3-none-any.whl (209kB)
#      |████████████████████████████████| 215kB 5.2MB/s
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
df=pd.read_csv("news.csv")
df
# Out:
#                                                 title  ...   category
# 0   moeldoko harap seni budaya bisa jadi magnet ku...  ...    Culture
# 1   seniman palestina sulap tembakan israel jadi k...  ...    Culture
# 2   sontek cara 56 kreator berpengaruh di dunia ci...  ...    Culture
# 3   intip pertunjukan fashion dalam balutan seni t...  ...    Culture
# 4   kenang benyamin sueb teater abnon gelar pement...  ...    Culture
# ..                                                ...  ...        ...
# 95           riset.aids.buntu.ilmuwan.dunia.putus.asa  ...  Kesehatan
# 96        pmi.luncurkan.aliansi.global.untuk.hivaids.  ...  Kesehatan
# 97    bali.masuk.lima.besar.jumlah.penderita.hivaids.  ...  Kesehatan
# 98      ketimpangan.gender.jadikan.wanita.rentan.hiv.  ...  Kesehatan
# 99               hepatitis.b.lebih.infeksius.dari.hiv  ...  Kesehatan
#
# [100 rows x 3 columns]

# %%
df = df.dropna()
print(df.shape)
# Out:
# (100, 3)

# %%
df
# Out:
#                                                 title  ...   category
# 0   moeldoko harap seni budaya bisa jadi magnet ku...  ...    Culture
# 1   seniman palestina sulap tembakan israel jadi k...  ...    Culture
# 2   sontek cara 56 kreator berpengaruh di dunia ci...  ...    Culture
# 3   intip pertunjukan fashion dalam balutan seni t...  ...    Culture
# 4   kenang benyamin sueb teater abnon gelar pement...  ...    Culture
# ..                                                ...  ...        ...
# 95           riset.aids.buntu.ilmuwan.dunia.putus.asa  ...  Kesehatan
# 96        pmi.luncurkan.aliansi.global.untuk.hivaids.  ...  Kesehatan
# 97    bali.masuk.lima.besar.jumlah.penderita.hivaids.  ...  Kesehatan
# 98      ketimpangan.gender.jadikan.wanita.rentan.hiv.  ...  Kesehatan
# 99               hepatitis.b.lebih.infeksius.dari.hiv  ...  Kesehatan
#
# [100 rows x 3 columns]

# %% [markdown]
# Text Preprocessing

# %%
df['text'] = df['text'].str.lower()
df['text'] = df['text'].str.replace(r'\d+','')
df['text'] = df['text'].str.replace('[^\w\s]','')

# %%
df['category'] = df['category'].str.lower()

# %%
df
# Out:
#                                                 title  ...   category
# 0   moeldoko harap seni budaya bisa jadi magnet ku...  ...    culture
# 1   seniman palestina sulap tembakan israel jadi k...  ...    culture
# 2   sontek cara 56 kreator berpengaruh di dunia ci...  ...    culture
# 3   intip pertunjukan fashion dalam balutan seni t...  ...    culture
# 4   kenang benyamin sueb teater abnon gelar pement...  ...    culture
# ..                                                ...  ...        ...
# 95           riset.aids.buntu.ilmuwan.dunia.putus.asa  ...  kesehatan
# 96        pmi.luncurkan.aliansi.global.untuk.hivaids.  ...  kesehatan
# 97    bali.masuk.lima.besar.jumlah.penderita.hivaids.  ...  kesehatan
# 98      ketimpangan.gender.jadikan.wanita.rentan.hiv.  ...  kesehatan
# 99               hepatitis.b.lebih.infeksius.dari.hiv  ...  kesehatan
#
# [100 rows x 3 columns]

# %% [markdown]
# Removing Emoji

# %%
df.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
# Out:
#                                                 title  ...   category
# 0   moeldoko harap seni budaya bisa jadi magnet ku...  ...    culture
# 1   seniman palestina sulap tembakan israel jadi k...  ...    culture
# 2   sontek cara 56 kreator berpengaruh di dunia ci...  ...    culture
# 3   intip pertunjukan fashion dalam balutan seni t...  ...    culture
# 4   kenang benyamin sueb teater abnon gelar pement...  ...    culture
# ..                                                ...  ...        ...
# 95           riset.aids.buntu.ilmuwan.dunia.putus.asa  ...  kesehatan
# 96        pmi.luncurkan.aliansi.global.untuk.hivaids.  ...  kesehatan
# 97    bali.masuk.lima.besar.jumlah.penderita.hivaids.  ...  kesehatan
# 98      ketimpangan.gender.jadikan.wanita.rentan.hiv.  ...  kesehatan
# 99               hepatitis.b.lebih.infeksius.dari.hiv  ...  kesehatan
#
# [100 rows x 3 columns]

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory,StopWordRemover, ArrayDictionary

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
from Sastrawi.StopWordRemover.StopWordRemoverFactory import StopWordRemoverFactory
from nltk.tokenize import word_tokenize
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()
factorya = StopWordRemoverFactory()
stopword = factorya.create_stop_word_remover()
df['text']=df['text'].apply(word_tokenize)
df['text']=df['text'].apply(lambda x: [stemmer.stem(y) for y in x])
df['text']=df['text'].apply(lambda x: [stopword.remove(y) for y in x])

# %%
df
# Out:
#                                                 title  ...   category
# 0   moeldoko harap seni budaya bisa jadi magnet ku...  ...    culture
# 1   seniman palestina sulap tembakan israel jadi k...  ...    culture
# 2   sontek cara 56 kreator berpengaruh di dunia ci...  ...    culture
# 3   intip pertunjukan fashion dalam balutan seni t...  ...    culture
# 4   kenang benyamin sueb teater abnon gelar pement...  ...    culture
# ..                                                ...  ...        ...
# 95           riset.aids.buntu.ilmuwan.dunia.putus.asa  ...  kesehatan
# 96        pmi.luncurkan.aliansi.global.untuk.hivaids.  ...  kesehatan
# 97    bali.masuk.lima.besar.jumlah.penderita.hivaids.  ...  kesehatan
# 98      ketimpangan.gender.jadikan.wanita.rentan.hiv.  ...  kesehatan
# 99               hepatitis.b.lebih.infeksius.dari.hiv  ...  kesehatan
#
# [100 rows x 3 columns]

# %%
save=df
save
# Out:
#                                                 title  ...   category
# 0   moeldoko harap seni budaya bisa jadi magnet ku...  ...    culture
# 1   seniman palestina sulap tembakan israel jadi k...  ...    culture
# 2   sontek cara 56 kreator berpengaruh di dunia ci...  ...    culture
# 3   intip pertunjukan fashion dalam balutan seni t...  ...    culture
# 4   kenang benyamin sueb teater abnon gelar pement...  ...    culture
# ..                                                ...  ...        ...
# 95           riset.aids.buntu.ilmuwan.dunia.putus.asa  ...  kesehatan
# 96        pmi.luncurkan.aliansi.global.untuk.hivaids.  ...  kesehatan
# 97    bali.masuk.lima.besar.jumlah.penderita.hivaids.  ...  kesehatan
# 98      ketimpangan.gender.jadikan.wanita.rentan.hiv.  ...  kesehatan
# 99               hepatitis.b.lebih.infeksius.dari.hiv  ...  kesehatan
#
# [100 rows x 3 columns]

# %% [markdown]
# Change Culture to 1 and Kesehatan to 0

# %%
for i in range(len(df['category'])) :
  if df['category'][i] == 'culture':
    df['category'][i]=1
  else :
    df['category'][i]=0

# %%
df['edited']=df['text']

# %% [markdown]
# Getting all the words

# %%
filter = df['category'] == '1'
dfcul = df[filter]
dfkes = df[~filter]

# %%
dfcul = dfcul['edited']
dfcul
# Out:
# Series([], Name: edited, dtype: object)

# %%
dfkes = dfkes['edited']
dfkes
# Out:
# 0     [kepala, staf, presiden, ri, jenderal, tni, pu...
# 1     [beda, , seniman, , umum, orang, seniman, majd...
# 2     [jadi, modal, utama, , , milik, tiap, orang, ,...
# 3     [, sabang, , merauke, indonesia, tawar, indah,...
# 4     [benyamin, suaeb, bukan, , sekadar, nama, soso...
#                             ...
# 95    [empat, abad, sejak, virus, , aids, temu, upay...
# 96    [palang, merah, indonesia, pmi, , federasi, in...
# 97    [derita, hivaids, , bal, cara, kumulatif, hing...
# 98    [ikat, perempuan, positif, indonesia, ippi, bu...
# 99    [lama, , , akrab, , istilah, hiv, , kenal, san...
# Name: text, Length: 100, dtype: object

# %%
def get_all_words(dataset):
    allword=[]
    for i in dataset:
        for y in i:
            allword.append(y)
    return allword
    
all_cul_words = get_all_words(dfcul)
all_kes_words = get_all_words(dfkes)
allword= get_all_words(df['edited'])

# %%
allword
# Out:
# ['kepala',
#  'staf',
#  'presiden',
#  'ri',
#  'jenderal',
#  'tni',
#  'purn',
#  'dr',
#  'moeldoko',
#  'hadir',
#  'pementasa',
#  'judul',
#  'langit',
#  'bidadari',
#  '',
#  'gedung',
#  'teater',
#  'garuda',
#  'taman',
#  'mini',
#  'indonesia',
#  'indah',
#  'jakarta',
#  'tepat',
#  '',
#  'ingat',
#  'hari',
#  'lahir',
#  'pancasila',
#  'juni',
#  '',
#  'sempat',
#  'sebut',
#  'moeldoko',
#  'ingat',
#  'seluruh',
#  'generasi',
#  'bangsa',
#  'betapa',
#  'kaya',
#  'budaya',
#  '',
#  'milik',
#  '',
#  'indonesialebih',
#  'lanjut',
#  'kaya',
#  'budaya',
#  '',
#  'turut',
#  'moeldoko',
#  '',
#  'jadi',
#  'instrumen',
#  '',
#  'tarik',
#  'minat',
#  'wisatawan',
#  'maupun',
#  'investor',
#  '',
#  'luar',
#  'negeri',
#  '',
#  'unjung',
#  '',
#  'kembang',
#  'bisnis',
#  '',
#  'indonesiabaca',
#  'jugadatanglah',
#  '',
#  'jamin',
#  '',
#  'wisatawan',
#  '',
#  'aman',
#  '',
#  'nyaman',
#  'nikmat',
#  'indonesia',
#  '',
#  'investor',
#  '',
#  'aman',
#  'investasi',
#  '',
#  'indonesia',
#  'ungkap',
#  'moeldokodalam',
#  'bagai',
#  'sempat',
#  'temu',
#  '',
#  'banyak',
#  'tokoh',
#  '',
#  'banyak',
#  'pihak',
#  'moeldoko',
#  'selalu',
#  'tegas',
#  '',
#  'aman',
#  '',
#  'negeri',
#  'indonesia',
#  'sangat',
#  'baik',
#  'sekalipun',
#  '',
#  'gelintir',
#  'oknum',
#  '',
#  '',
#  'rusak',
#  '',
#  'tekan',
#  '',
#  'aparat',
#  'aman',
#  'sangat',
#  'sigap',
#  '',
#  'tindak',
#  'cepat',
#  '',
#  'atas',
#  'aksiaksi',
#  'keras',
#  '',
#  'teror',
#  'diri',
#  'jamin',
#  '',
#  'perintah',
#  'laku',
#  'upaya',
#  'maksimal',
#  '',
#  'lindung',
#  'tiap',
#  'warga',
#  'masuk',
#  'tingkat',
#  'sejahtera',
#  'ekonomi',
#  'masyarakat',
#  'lalu',
#  'investasi',
#  '',
#  'segenap',
#  'penjuru',
#  'negeri',
#  '',
#  'bidang',
#  'pariwisata',
#  'indonesia',
#  '',
#  'tunjuk',
#  'tingkat',
#  'kunjung',
#  '',
#  'sangat',
#  'besar',
#  'banding',
#  'negaranegara',
#  '',
#  '',
#  'asia',
#  'tenggara',
#  '',
#  'milik',
#  'kaya',
#  '',
#  'indah',
#  'alam',
#  '',
#  'luar',
#  'biasa',
#  'seni',
#  '',
#  'budaya',
#  '',
#  'akar',
#  'cara',
#  'kuat',
#  '',
#  'tengah',
#  'masyarakat',
#  '',
#  'jadi',
#  'magnet',
#  '',
#  'wisatawan',
#  '',
#  'seluruh',
#  'dunia',
#  '',
#  'unjung',
#  'indonesia',
#  'pariwisata',
#  '',
#  '',
#  'gerak',
#  'ekonomi',
#  'cara',
#  'cepat',
#  '',
#  'dorong',
#  'titiktitik',
#  'ekonomi',
#  'baru',
#  '',
#  'hampir',
#  'seluruh',
#  'penjuru',
#  'negeripertunjukan',
#  'seni',
#  'teater',
#  'emban',
#  'misi',
#  '',
#  'lebih',
#  'harga',
#  '',
#  'peduli',
#  '',
#  'budaya',
#  'negeri',
#  'sendiri',
#  '',
#  'kaya',
#  'alam',
#  'indonesia',
#  'kaya',
#  'alam',
#  '',
#  'budaya',
#  '',
#  'waris',
#  '',
#  '',
#  'selalu',
#  'jaga',
#  '',
#  'lestari',
#  '',
#  '',
#  'pagelaran',
#  'seni',
#  '',
#  'tuju',
#  'beri',
#  'didik',
#  '',
#  'masyarakat',
#  'lalu',
#  'tunjuk',
#  'seni',
#  '',
#  'bangkit',
#  'cinta',
#  '',
#  '',
#  'budaya',
#  'bangsa',
#  '',
#  'gelora',
#  'semangat',
#  'bangsa',
#  'pink',
#  'beachpertunjukan',
#  '',
#  'sutradara',
#  '',
#  'harry',
#  'de',
#  'fretes',
#  'sebut',
#  'ambil',
#  'cerita',
#  'latar',
#  'belakang',
#  'kisah',
#  'klasik',
#  'wayang',
#  'jaka',
#  'tarub',
#  'tokoh',
#  'sentral',
#  'jaka',
#  'tarub',
#  'peran',
#  '',
#  'samuel',
#  'rizal',
#  'sedang',
#  'aktris',
#  'senior',
#  'jajang',
#  'c',
#  'noer',
#  'didapuk',
#  'bagai',
#  'ibunda',
#  'jaka',
#  'tarub',
#  '',
#  'tujuh',
#  'bidadari',
#  'peran',
#  '',
#  'artisartis',
#  'lintas',
#  'generasi',
#  'mulai',
#  '',
#  'indi',
#  'barends',
#  'ariel',
#  'tatum',
#  'kezia',
#  'warouw',
#  'sarwendah',
#  'tan',
#  'ersa',
#  'mayor',
#  'ririn',
#  'ekawati',
#  '',
#  'sophia',
#  'latjubaproduser',
#  'pagelaran',
#  'teater',
#  'sari',
#  'kata',
#  '',
#  'pagelaran',
#  'sebut',
#  'maksud',
#  '',
#  'bangkit',
#  '',
#  'cinta',
#  'masyarakat',
#  'hadap',
#  'budaya',
#  'bangsa',
#  'lalu',
#  'pagelaran',
#  '',
#  '',
#  'dukung',
#  'tunjuk',
#  '',
#  'beri',
#  'pesan',
#  '',
#  'seluruh',
#  'masyarakat',
#  'indonesia',
#  '',
#  'seni',
#  '',
#  'budaya',
#  'bangkit',
#  '',
#  '',
#  '',
#  'samasama',
#  '',
#  '',
#  '',
#  'tikai',
#  '',
#  '',
#  'damai',
#  'ujarnyacopyright',
#  'kly',
#  'kapanlagi',
#  'youniverse',
#  'all',
#  'rights',
#  'reserved',
#  'beda',
#  '',
#  'seniman',
#  '',
#  'umum',
#  'orang',
#  'seniman',
#  'majdy',
#  'abu',
#  'tagiyya',
#  'cipta',
#  'karya',
#  'seni',
#  '',
#  'selongsong',
#  'peluru',
#  '',
#  'mortir',
#  '',
#  'tembak',
#  'tentara',
#  'israel',
#  '',
#  'jalur',
#  'gazaseperti',
#  '',
#  'kutip',
#  '',
#  'laman',
#  'selasa',
#  'majdy',
#  'kata',
#  'diri',
#  '',
#  '',
#  'kirim',
#  'pesan',
#  'damai',
#  '',
#  'semua',
#  'orang',
#  '',
#  'duniam',
#  'lalu',
#  'karya',
#  'seni',
#  '',
#  'dihasilkannyabaca',
#  'jugaorangorang',
#  'gaza',
#  'bukan',
#  'teroris',
#  '',
#  'sama',
#  '',
#  '',
#  'orang',
#  '',
#  '',
#  'cinta',
#  'damai',
#  'ungkap',
#  'majdy',
#  'sang',
#  'seniman',
#  '',
#  'kumpul',
#  'bahanbahan',
#  'sisa',
#  'peluru',
#  '',
#  'tembak',
#  '',
#  'demonstran',
#  '',
#  'tempat',
#  'bekas',
#  'konflik',
#  '',
#  '',
#  '',
#  '',
#  'dokter',
#  'bahkan',
#  'tak',
#  '',
#  'peluru',
#  'diri',
#  '',
#  'manfaat',
#  'barangbarang',
#  'rumah',
#  'tangga',
#  '',
#  'jadi',
#  'sasar',
#  'mortir',
#  'israel',
#  '',
#  'kompor',
#  'gas',
#  'portabel',
#  'hingga',
#  'pancikaryakarya',
#  'majdy',
#  'kerap',
#  'nada',
#  'protes',
#  'hadap',
#  'tindak',
#  'tentara',
#  'israel',
#  'diri',
#  'pernah',
#  'sentil',
#  'tentara',
#  'israel',
#  '',
#  'buat',
#  'patung',
#  'bagai',
#  'bentuk',
#  'empati',
#  'atas',
#  'bunuh',
#  'orang',
#  'jurnalis',
#  '',
#  'sedang',
#  'liput',
#  'konflik',
#  '',
#  'gazakarya',
#  'seni',
#  'sebut',
#  'tampil',
#  'jaket',
#  'antipeluru',
#  '',
#  'tulis',
#  'putih',
#  '',
#  'atas',
#  'rupa',
#  'kata',
#  'pers',
#  'lalu',
#  'karya',
#  'seni',
#  '',
#  '',
#  'buat',
#  '',
#  '',
#  'lihat',
#  'tingkat',
#  'sengsara',
#  '',
#  'derita',
#  '',
#  'orangorang',
#  'gaza',
#  '',
#  '',
#  'manusia',
#  '',
#  '',
#  'memberitahu',
#  'orang',
#  '',
#  '',
#  '',
#  '',
#  'manusia',
#  '',
#  'saudarasaudaramu',
#  '',
#  'manusia',
#  '',
#  '',
#  'pesan',
#  '',
#  '',
#  'dunia',
#  '',
#  '',
#  'orangorang',
#  '',
#  '',
#  'hidup',
#  'ungkap',
#  'majdytinggal',
#  '',
#  'kamp',
#  'ungsi',
#  'nuseirat',
#  '',
#  'jalur',
#  'gaza',
#  'buat',
#  'sang',
#  'seniman',
#  'perlu',
#  'juang',
#  '',
#  'tahan',
#  'hidup',
#  '',
#  'cari',
#  'nafkah',
#  '',
#  'karyakarya',
#  'seni',
#  '',
#  'hasil',
#  'awat',
#  'palestina',
#  'razan',
#  'alnajar',
#  '',
#  'tewas',
#  'tembak',
#  'tentara',
#  'israel',
#  'jumat',
#  'lalu',
#  'dimakamkancopyright',
#  'kly',
#  'kapanlagi',
#  'youniverse',
#  'all',
#  'rights',
#  'reserved',
#  'jadi',
#  'modal',
#  'utama',
#  '',
#  '',
#  'milik',
#  'tiap',
#  'orang',
#  '',
#  'terus',
#  'kembang',
#  '',
#  'bidang',
#  '',
#  'gelut',
#  'lantas',
#  'bagaimana',
#  '',
#  '',
#  'habis',
#  'kreativitas',
#  'kreator',
#  'paling',
#  'pengaruh',
#  '',
#  'dunia',
#  '',
#  'bidang',
#  'olahraga',
#  '',
#  'industri',
#  'kreatif',
#  '',
#  'bidang',
#  'olahraga',
#  'beri',
#  'jawab',
#  'satu',
#  'kreator',
#  '',
#  'buah',
#  'kampanye',
#  'judul',
#  'tuju',
#  '',
#  'inspirasi',
#  'kreator',
#  '',
#  'bagai',
#  'cabang',
#  '',
#  'budaya',
#  'olahraga',
#  '',
#  'jadi',
#  'berani',
#  '',
#  'prediksi',
#  '',
#  'mimpi',
#  '',
#  'sendiribaca',
#  'jugalewat',
#  'buah',
#  'film',
#  'tonton',
#  '',
#  'bawa',
#  'lewat',
#  'pintu',
#  'belakang',
#  'tuju',
#  'panggung',
#  '',
#  'saksi',
#  'tunjuk',
#  '',
#  'beda',
#  '',
#  '',
#  '',
#  '',
#  'kreator',
#  '',
#  'bagai',
#  'cabang',
#  'olahraga',
#  'muncul',
#  '',
#  'bersiapsiap',
#  'tunjuk',
#  'kreativitas',
#  'unik',
#  'merekajose',
#  'mourinho',
#  'arah',
#  '',
#  'belakang',
#  'panggung',
#  'bawa',
#  'luis',
#  'suarez',
#  'von',
#  'miller',
#  'gabriel',
#  'jesus',
#  'karlie',
#  'kloss',
#  '',
#  '',
#  '',
#  'atas',
#  'panggungsaat',
#  'tunjuk',
#  'mulai',
#  'host',
#  'aap',
#  'ferg',
#  'ucap',
#  'katakata',
#  '',
#  'bawa',
#  'tonton',
#  'tenggelam',
#  '',
#  'tunjuk',
#  'kreativitas',
#  'ikon',
#  'sepakbola',
#  'paul',
#  'pogba',
#  '',
#  'keliling',
#  '',
#  'atlet',
#  '',
#  'inspirasi',
#  '',
#  'gerakgeriknya',
#  'beri',
#  'sentuh',
#  'kreativitas',
#  '',
#  '',
#  '',
#  'ulang',
#  '',
#  'main',
#  'alhasil',
#  'cipta',
#  'buah',
#  'kreativitas',
#  'baru',
#  'gaya',
#  'freestyle',
#  '',
#  'terkenalleo',
#  'messi',
#  '',
#  '',
#  'libat',
#  '',
#  'kampanye',
#  'creativity',
#  'is',
#  'the',
#  'answer',
#  '',
#  'masuk',
#  'kreativitas',
#  '',
#  'tiap',
#  'main',
#  '',
#  'lapang',
#  'momen',
#  'kreativitas',
#  '',
#  'ubah',
#  'suatu',
#  'main',
#  'kamu',
#  '',
#  'lihat',
#  'halhal',
#  '',
#  '',
#  'lihat',
#  'orang',
#  '',
#  '',
#  'ambil',
#  'sempat',
#  '',
#  '',
#  'ambil',
#  'orang',
#  '',
#  'kreativitas',
#  'pisah',
#  '',
#  'main',
#  '',
#  'ujar',
#  'leo',
#  'messibintang',
#  'sepakbola',
#  '',
#  '',
#  'pensiun',
#  'david',
#  'beckham',
#  '',
#  '',
#  'soal',
#  '',
#  '',
#  'kreativitas',
#  '',
#  'film',
#  'sebut',
#  'momenmomen',
#  '',
#  'paling',
#  '',
#  'bangga',
#  'baik',
#  '',
#  'luar',
#  '',
#  '',
#  'lapang',
#  '',
#  '',
#  'teknik',
#  'kerja',
#  'keras',
#  '',
#  'kreativitas',
#  'gabung',
#  'jadi',
#  'satu',
#  '',
#  '',
#  '',
#  'kerja',
#  'keras',
#  '',
#  'sedikit',
#  'faktor',
#  'untung',
#  'imbuh',
#  'beckhamdi',
#  'hujung',
#  'film',
#  'leo',
#  'messi',
#  'sang',
#  'legenda',
#  'inspirasi',
#  'tonton',
#  '',
#  'buang',
#  'naskah',
#  '',
#  '',
#  '',
#  'buat',
#  'atur',
#  '',
#  'sendiri',
#  'film',
#  '',
#  'akhir',
#  '',
#  'pharrell',
#  'beri',
#  'mic',
#  '',
#  'tonton',
#  'buah',
#  'panggil',
#  '',
#  '',
#  'semua',
#  '',
#  'cipta',
#  'jawabannyasebuah',
#  'call',
#  'to',
#  'action',
#  '',
#  'adidas',
#  '',
#  'konsumen',
#  '',
#  'seluruh',
#  'dunia',
#  'undang',
#  '',
#  'atlet',
#  'musisi',
#  'artis',
#  '',
#  'buat',
#  'film',
#  '',
#  'kotakota',
#  'global',
#  'london',
#  'los',
#  'angeles',
#  'tokyo',
#  'paris',
#  'shanghai',
#  'new',
#  'yorkdan',
#  'tuan',
#  'rumah',
#  'moscow',
#  '',
#  '',
#  'luput',
#  'indonesia',
#  '',
#  'cipta',
#  '',
#  'bentuk',
#  'narasi',
#  'brand',
#  '',
#  'sisa',
#  'kampanye',
#  '',
#  'jalan',
#  'lama',
#  'event',
#  'world',
#  'cupgambargambar',
#  'momen',
#  '',
#  'konten',
#  '',
#  'cipta',
#  '',
#  'adidas',
#  '',
#  '',
#  'cipta',
#  '',
#  'bentuk',
#  'buah',
#  'kampanye',
#  'opensourced',
#  '',
#  'pertama',
#  'kali',
#  'hadir',
#  '',
#  'jadi',
#  'denyut',
#  'nyata',
#  '',
#  'acara',
#  'olahraga',
#  'besar',
#  '',
#  'duniapharrell',
#  'williams',
#  'rangkum',
#  '',
#  '',
#  'kreatifitas',
#  '',
#  'serap',
#  'pengalamanpengalaman',
#  'yangunik',
#  '',
#  'kamu',
#  'bagai',
#  'individu',
#  '',
#  ...]

# %% [markdown]
# Using Word 2 Vec

# %% [markdown]
# Word2vec is a two layer neural network that is trained to change word into vector so that the words can be understand by a deep learning model.
#   From a large corpus of word it will produce a vector space, with each unique  word in a corpus being assign a vector in the space.
#   Using a neural network word2vec take input as one-hot vectors, which is a vector with the same length, filled with zero excepet the index that represent the word we want to repesent, assign "1".
#
# the rows of hidden layer weight matrix, are actually the word vector, it operates as a lookup table. The output, is just a word vector of the input word.
#
# and the output layer is just a softmax activation function.

# %%
from gensim.models import Word2Vec 

# Create CBOW model 
model = Word2Vec([allword], min_count = 1, size = 100, window = 5)
#setup the parameter of the model one by1
print(model.wv.vocab)
print(model.wv.syn0)
print(model.wv.syn0.shape)

filename="word2vecembedding.txt"
model.wv.save_word2vec_format(filename,binary=False)
# Out:
# {'kepala': <gensim.models.keyedvectors.Vocab object at 0x7fc1d6bdaa20>, 'staf': <gensim.models.keyedvectors.Vocab object at 0x7fc234d4ec88>, 'presiden': <gensim.models.keyedvectors.Vocab object at 0x7fc234d4ecf8>, 'ri': <gensim.models.keyedvectors.Vocab object at 0x7fc1d6bc8ef0>, 'jenderal': <gensim.models.keyedvectors.Vocab object at 0x7fc1d6625550>, 'tni': <gensim.models.keyedvectors.Vocab object at 0x7fc1d588dac8>, 'purn': <gensim.models.keyedvectors.Vocab object at 0x7fc1d588ddd8>, 'dr': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5447e80>, 'moeldoko': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2978>, 'hadir': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f29b0>, 'pementasa': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f29e8>, 'judul': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2a20>, 'langit': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2a58>, 'bidadari': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2a90>, '': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2ac8>, 'gedung': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2b00>, 'teater': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2b38>, 'garuda': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2b70>, 'taman': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2ba8>, 'mini': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2be0>, 'indonesia': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2c18>, 'indah': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2c50>, 'jakarta': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2c88>, 'tepat': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2cc0>, 'ingat': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2cf8>, 'hari': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2d30>, 'lahir': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2d68>, 'pancasila': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2da0>, 'juni': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2dd8>, 'sempat': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2e10>, 'sebut': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2e48>, 'seluruh': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2e80>, 'generasi': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2eb8>, 'bangsa': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2ef0>, 'betapa': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2f28>, 'kaya': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2f60>, 'budaya': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2f98>, 'milik': <gensim.models.keyedvectors.Vocab object at 0x7fc1d53f2fd0>, 'indonesialebih': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401048>, 'lanjut': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401080>, 'turut': <gensim.models.keyedvectors.Vocab object at 0x7fc1d54010b8>, 'jadi': <gensim.models.keyedvectors.Vocab object at 0x7fc1d54010f0>, 'instrumen': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401128>, 'tarik': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401160>, 'minat': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401198>, 'wisatawan': <gensim.models.keyedvectors.Vocab object at 0x7fc1d54011d0>, 'maupun': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401208>, 'investor': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401240>, 'luar': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401278>, 'negeri': <gensim.models.keyedvectors.Vocab object at 0x7fc1d54012b0>, 'unjung': <gensim.models.keyedvectors.Vocab object at 0x7fc1d54012e8>, 'kembang': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401320>, 'bisnis': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401358>, 'indonesiabaca': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401390>, 'jugadatanglah': <gensim.models.keyedvectors.Vocab object at 0x7fc1d54013c8>, 'jamin': <gensim.models.keyedvectors.Vocab object at 0x7fc1d5401400>, 'aman': <gensim.m ...
# [[-6.40540719e-01 -1.14189410e+00 -5.23271680e-01 ... -2.07640991e-01
#   -1.26709557e+00  3.43132764e-01]
#  [-2.05605760e-01 -3.73617828e-01 -1.70274392e-01 ... -6.92651197e-02
#   -4.14774567e-01  1.10563315e-01]
#  [-2.59650052e-01 -4.63483483e-01 -2.11438566e-01 ... -8.74360502e-02
#   -5.12630820e-01  1.34737715e-01]
#  ...
#  [ 4.91927052e-03 -1.12114695e-03 -4.70891735e-03 ... -3.55055626e-03
#   -4.61961003e-03  1.88785454e-03]
#  [ 2.89462460e-03  4.46480419e-03 -1.71062350e-03 ...  1.89078026e-04
#   -9.84588623e-05  4.93758172e-03]
#  [-3.10002267e-03  2.33333977e-03  1.76195137e-03 ...  1.95618090e-03
#    4.03593108e-03  4.72985860e-03]]
# (5048, 100)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).
#   import sys
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.wv.vectors instead).

# %% [markdown]
# read the "word2vecembedding.txt" and take the value,word, and the index.

# %%
import os
embeddings_index = {}
f= open(os.path.join('','word2vecembedding.txt'),encoding="utf-8")
for line in f:
  values = line.split()
  word = values[0]
  coefs= np.asarray(values[1:])
  embeddings_index[word]=coefs
f.close()

# %%
len(embeddings_index)
# Out:
# 5049

# %% [markdown]
# Using keras we take tokenzier and fit the transformed dataset and using pad_sequences we pad the vector so that all of the input have the same width of vector.

# %%
from tensorflow.python.keras.preprocessing.text import Tokenizer
from tensorflow.python.keras.preprocessing.sequence import pad_sequences

tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(df['edited'])
total_reviews = df['edited'].values

sequences = tokenizer_obj.texts_to_sequences(df['edited'])

max_length = max([len(i) for i in total_reviews])
print(max_length)


#pad
word_index= tokenizer_obj.word_index
review_pad = pad_sequences(sequences,maxlen=max_length)
sentiment = df['category'].values
print(review_pad)
print(sentiment.shape)

#define vocab size
vocab_size = len(tokenizer_obj.word_index)+1
print(vocab_size)
# Out:
# 1553
# [[   0    0    0 ...   76   77   78]
#  [   0    0    0 ...   76   77   78]
#  [   0    0    0 ...   76   77   78]
#  ...
#  [   0    0    0 ...    8  131 1651]
#  [   0    0    0 ...    1 2295   79]
#  [   0    0    0 ...   83  595  146]]
# (100,)
# 5049

# %% [markdown]
# Form all of the matrix above, we transform the word into vector form the word2vec data by picking the corresponding index.

# %%
num_words = len(word_index)+1
embedding_matrix = np.zeros((num_words,100))
for word, i in word_index.items():
  if i>num_words:
    continue
  embedding_vector = embeddings_index.get(word)
  if embedding_vector is not None:
    embedding_matrix[i] = embedding_vector

# %%
print(num_words)
# Out:
# 5049

# %%
pip install keras_metrics
# Out:
# Collecting keras_metrics
#   Downloading https://files.pythonhosted.org/packages/32/c9/a87420da8e73de944e63a8e9cdcfb1f03ca31a7c4cdcdbd45d2cdf13275a/keras_metrics-1.1.0-py2.py3-none-any.whl
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.6/dist-packages (from keras_metrics) (2.4.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.1.5->keras_metrics) (1.19.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py->Keras>=2.1.5->keras_metrics) (1.15.0)
# Installing collected packages: keras-metrics
# Successfully installed keras-metrics-1.1.0

# %% [markdown]
# These are the BPNN model using keras, in keras the model automaticly use BPNN so we only need to specify the model, the input layer consist of how many the length is and for the hidden layer we use 32 hidden layer. And 1 dense layer of the output.

# %%
from keras import Sequential
from keras.layers import Dense,Embedding,LSTM,GRU
from keras.layers.embeddings import Embedding
import keras_metrics

EMBEDDING_DIM = 100

model= Sequential()
model.add(Embedding(vocab_size,EMBEDDING_DIM,input_length=max_length))
model.add(GRU(units=32, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy',keras_metrics.precision(), keras_metrics.recall(),keras_metrics.f1_score()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 1553, 100)         504900
# _________________________________________________________________
# gru (GRU)                    (None, 32)                12864
# _________________________________________________________________
# dense (Dense)                (None, 16)                528
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 518,309
# Trainable params: 518,309
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# spliting the data into 70% trainning
# 30% testing

# %%
VALIDATION_SPLIT = 0.3
indices=np.arange(review_pad.shape[0])

review_pad = review_pad[indices]
sentiment = sentiment[indices]
num_validation_samples = int (VALIDATION_SPLIT*review_pad.shape[0])
x_train_pad = review_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]
x_test_pad = review_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

print(x_train_pad.shape)
print(y_train.shape)
print(x_test_pad.shape)
print(y_test.shape)
# Out:
# (70, 1553)
# (70,)
# (30, 1553)
# (30,)

# %%
review_pad.shape
# Out:
# (100, 1553)

# %%
sentiment.shape
# Out:
# (100,)

# %%
x_cul=review_pad[:49]
y_cul=sentiment[:49]

# %%
x_kes=review_pad[50:]
y_kes=sentiment[50:]

# %%
x_train=x_cul[:30]
y_train=y_cul[:30]

# %%
x_train.shape
# Out:
# (30, 1553)

# %%
y_train.shape
# Out:
# (30,)

# %%
x_test=x_cul[31:]
y_test=y_cul[31:]

# %%
x_test.shape
# Out:
# (18, 1553)

# %%
y_test.shape
# Out:
# (18,)

# %%
x_train = np.append(x_train,x_kes[:30],axis=0)
y_train = np.append(y_train,y_kes[:30],axis=0)

# %%
x_train.shape
# Out:
# (60, 1553)

# %%
y_train.shape
# Out:
# (60,)

# %%
x_test = np.append(x_test,x_kes[31:],axis=0)
y_test = np.append(y_test,y_kes[31:],axis=0)

# %%
x_test.shape
# Out:
# (37, 1553)

# %%
y_test.shape
# Out:
# (37,)

# %%
y_train = np.asarray(y_train).astype('float32')
y_test = np.asarray(y_test).astype('float32')

# %%
print("Train...")
themodel = model.fit(x_train,y_train, epochs= 10, validation_data=(x_test,y_test))
# Out:
# Train...
# Epoch 1/10
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/base_layer.py:1402: UserWarning: `layer.updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`layer.updates` will be removed in a future version. '
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 2/2 [==============================] - ETA: 0s - loss: 0.7001 - accuracy: 0.2594 - precision: 0.0312 - recall: 0.0167 - f1_score: 0.0217            WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# WARNING:tensorflow:`add_update` `inputs` kwarg has been deprecated. You no longer need to pass a value to `inputs` as it is being automatically inferred.
# 2/2 [==============================] - 9s 3s/step - loss: 0.6996 - accuracy: 0.2729 - precision: 0.0417 - recall: 0.0222 - f1_score: 0.0290 - val_loss: 0.6893 - val_accuracy: 0.8378 - val_precision: 0.7841 - val_recall: 1.0000 - val_f1_score: 0.8786
# Epoch 2/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.6878 - accuracy: 0.8486 - precision: 0.7193 - recall: 1.0000 - f1_score: 0.8358 - val_loss: 0.6834 - val_accuracy: 0.9189 - val_precision: 0.8571 - val_recall: 1.0000 - val_f1_score: 0.9231
# Epoch 3/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.6792 - accuracy: 0.9785 - precision: 0.9522 - recall: 1.0000 - f1_score: 0.9755 - val_loss: 0.6769 - val_accuracy: 0.9189 - val_precision: 0.8571 - val_recall: 1.0000 - val_f1_score: 0.9231
# Epoch 4/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.6689 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.6692 - val_accuracy: 0.9459 - val_precision: 0.9000 - val_recall: 1.0000 - val_f1_score: 0.9474
# Epoch 5/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.6598 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.6605 - val_accuracy: 0.9730 - val_precision: 0.9474 - val_recall: 1.0000 - val_f1_score: 0.9730
# Epoch 6/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.6472 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.6515 - val_accuracy: 0.9730 - val_precision: 0.9474 - val_recall: 1.0000 - val_f1_score: 0.9730
# Epoch 7/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.6337 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.6408 - val_accuracy: 0.9730 - val_precision: 0.9474 - val_recall: 1.0000 - val_f1_score: 0.9730
# Epoch 8/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.6189 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.6280 - val_accuracy: 0.9730 - val_precision: 0.9474 - val_recall: 1.0000 - val_f1_score: 0.9730
# Epoch 9/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.6012 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.6135 - val_accuracy: 0.9730 - val_precision: 0.9474 - val_recall: 1.0000 - val_f1_score: 0.9730
# Epoch 10/10
# 2/2 [==============================] - 4s 2s/step - loss: 0.5814 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000 - f1_score: 1.0000 - val_loss: 0.5969 - val_accuracy: 0.9730 - val_precision: 0.9474 - val_recall: 1.0000 - val_f1_score: 0.9730

# %% [markdown]
# 1 B

# %% [markdown]
# Berdasarkan hasil di atas dapat dilihat bahwa hasil accuracy yang hasilkan cukup besar yang dimana hasil ini cukup akurat.
# Kita juga dapat melihat dimana hasil precision dari model di atas 1 yang dimana berarti semua yang di jalankan mendapatkan hasil yang sama.
# kemudian pada val accuracy dapat di lihat nilainya 1 yang dimana menunjukkan bahwa modelnya sangat akurat.

# %% [markdown]
# 1 C

# %% [markdown]
# Dari model deep learning di atas sangatlah simple yang dimana menggunakan word2vec kemudian digabungkan dengan model Connected Layer yang dimana input layernya merupakan berapa banyak kata yang ada dan hidden layer yang berjumlah 32 kemudian dengan 2 dense layer.

# %% [markdown]
# Source

# %% [markdown]
# https://medium.com/@ksnugroho/dasar-text-preprocessing-dengan-python-a4fa52608ffe
#
# https://medium.com/@datamonsters/text-preprocessing-in-python-steps-tools-and-examples-bf025f872908
#
# https://www.digitalocean.com/community/tutorials/how-to-perform-sentiment-analysis-in-python-3-using-the-natural-language-toolkit-nltk
#
# https://www.geeksforgeeks.org/python-word-embedding-using-word2vec/
#
# https://www.kaggle.com/pierremegret/gensim-word2vec-tutorial
#
# https://towardsdatascience.com/machine-learning-word-embedding-sentiment-classification-using-keras-b83c28087456
#
# https://israelg99.github.io/2017-03-23-Word2Vec-Explained/
